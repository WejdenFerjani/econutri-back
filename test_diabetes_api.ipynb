# %%
# !pip install requests==2.32.3

# %%
import requests
# Out:
# Running cells with 'venv (Python 3.13.6)' requires the ipykernel package.
#
# Install 'ipykernel' into the Python environment.
#
# Command: 'c:/Users/Wejden/Desktop/projet-Web/back/Diabetes-Prediction-CRISPDM/venv/Scripts/python.exe -m pip install ipykernel -U --force-reinstall'

# %%
url = "http://127.0.0.1:5000/predict"

# %%
data = {
    "Pregnancies": 6,
    "Glucose": 148,
    "BloodPressure": 72,
    "SkinThickness": 35,
    "Insulin": 0,
    "BMI": 33.6,
    "DiabetesPedigreeFunction": 0.627,
    "Age":50
}

# %%
# data = {
#     "Pregnancies": 6,
#     "Glucose": 148,
#     "BloodPressure": 72,
#     "SkinThickness": 35,
#     "Insulin": 0,
#     "BMI": 33.6,
#     "DiabetesPedigreeFunction": 0.627,
# }

# %%
response = requests.post(url, json=data)
print(response)
print(response.json())
